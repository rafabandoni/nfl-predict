# %% [markdown]
# <a href="https://colab.research.google.com/github/rafabandoni/nfl-predict/blob/main/notebooks/00_nfl_predict_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # 00. Loading and Cleaning Data

# %% [markdown]
# ## Creating dataframes

# %%
# Iter over a list so we don't need to call each df individually
data_list = [
  'defense_downs',
  'defense_fumbles',
  'defense_interceptions',
  'defense_passing',
  'defense_receiving',
  'defense_rushing',
  'defense_scoring',
  'defense_tackles',
  'offense_downs',
  'offense_passing',
  'offense_receiving',
  'offense_rushing',
  'offense_scoring',
  'special-teams_field-goals',
  'special-teams_kickoff-returns',
  'special-teams_kickoffs',
  'special-teams_punt-returns',
  'special-teams_punting',
  'special-teams_scoring',
]

# %%
dataframe_dict = {}
for item in data_list:
  data = pd.read_csv(f'https://raw.githubusercontent.com/rafabandoni/nfl-predict/refs/heads/main/data/{item}.csv')
  dataframe_dict[item] = data

# %%
# Unpack dict into each of the dataframe variables
(
  defense_downs,
  defense_fumbles,
  defense_interceptions,
  defense_passing,
  defense_receiving,
  defense_rushing,
  defense_scoring,
  defense_tackles,
  offense_downs,
  offense_passing,
  offense_receiving,
  offense_rushing,
  offense_scoring,
  special_teams_field_goals,
  special_teams_kickoff_returns,
  special_teams_kickoffs,
  special_teams_punt_returns,
  special_teams_punting,
  special_teams_scoring
) = tuple(dataframe_dict.values())

# %%
# Test
offense_rushing.head()
# Out:
#       Team  Att  Rush Yds  YPC  TD  20+  40+  \
# 0   Chiefs  556      2627  4.7  13   15    4
# 1     Jets  534      2374  4.4  14   11    2
# 2  Jaguars  512      2395  4.7  14   14    1
# 3  Raiders  504      2494  5.0  19   27    6
# 4  Falcons  497      1891  3.8  14   12    1
#
#                                          Lng  Rush 1st  Rush 1st%  Rush FUM  \
# 0                      80T                         129       23.2         7
# 1                       53                         118       22.1        11
# 2                       74                         148       28.9         8
# 3                       71                         113       22.4         9
# 4                       55                         111       22.3         4
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010

# %% [markdown]
# ## Cleaning data

# %% [markdown]
# ### Joining dataframes
#
# So we can work with all as one.

# %% [markdown]
# Let's start joining and treating all defense data.

# %% [markdown]
# In order to do better code and avoid repetitions, let's create a function!
#
# **Note**: In class, let's first create the code and then the function

# %%
def get_df_name(df):
  name =[x for x in globals() if globals()[x] is df][0]
  return name

def change_dataframes_columns(dataframes_list):
  keep_names = ['year', 'Team']
  for df in dataframes_list:
    df_name = get_df_name(df)
    new_columns = []
    for column in df.columns:
      if not column in (keep_names):
        new_name = f'{df_name}_{column}'
      else:
        new_name = column
      new_columns.append(new_name)
    df.columns = new_columns

def merge_dataframes(dataframes_list):
  new_dataframe = dataframes_list[0].copy()
  for df in dataframes_list[1:]:
    new_dataframe = new_dataframe.merge(df,
                                        on=['year', 'Team'],
                                        how='left')
  return new_dataframe

# %%
defense_dfs = [
  defense_downs,
  defense_fumbles,
  defense_interceptions,
  defense_passing,
  defense_receiving,
  defense_rushing,
  defense_scoring,
  defense_tackles,
]

change_dataframes_columns(defense_dfs)
defense_dataframe = merge_dataframes(defense_dfs)

defense_dataframe.head()
# Out:
#        Team  defense_downs_3rd Att  defense_downs_3rd Md  \
# 0     Lions                    198                    77
# 1   Falcons                    201                    79
# 2      Rams                    221                    74
# 3      Jets                    219                    81
# 4  Dolphins                    226                    84
#
#    defense_downs_4th Att  defense_downs_4th Md  defense_downs_Rec 1st  \
# 0                     12                     5                    187
# 1                     17                     9                    183
# 2                     12                     6                    191
# 3                      6                     4                    169
# 4                     22                     8                    166
#
#    defense_downs_Rec 1st%  defense_downs_Rush 1st  defense_downs_Rush 1st%  \
# 0                    56.7                      98                     22.1
# 1                    50.3                      87                     23.8
# 2                    58.2                      88                     21.8
# 3                    62.8                      70                     17.2
# 4                    57.6                      84                     18.8
#
#    defense_downs_Scrm Plys  ...  defense_rushing_Rush 1st  \
# 0                     1005  ...                        98
# 1                      957  ...                        87
# 2                     1017  ...                        88
# 3                      979  ...                        70
# 4                      988  ...                        84
#
#    defense_rushing_Rush 1st%  defense_rushing_Rush FUM  defense_scoring_FR TD  \
# 0                       22.1                         8                      1
# 1                       23.8                         8                      1
# 2                       21.8                         5                      0
# 3                       17.2                        12                      0
# 4                       18.8                         4                      1
#
#    defense_scoring_SFTY  defense_scoring_INT TD  defense_tackles_Sck  \
# 0                     1                       2                   44
# 1                     0                       2                   31
# 2                     0                       0                   43
# 3                     0                       3                   40
# 4                     1                       0                   39
#
#    defense_tackles_Comb  defense_tackles_Asst defense_tackles_Solo
# 0                   949                   246                  743
# 1                   873                   179                  686
# 2                   861                   127                  770
# 3                   835                   181                  633
# 4                   869                   156                  739
#
# [5 rows x 62 columns]

# %%
offense_dfs = [
  offense_downs,
  offense_passing,
  offense_receiving,
  offense_rushing,
  offense_scoring,
]

change_dataframes_columns(offense_dfs)
offense_dataframe = merge_dataframes(offense_dfs)

offense_dataframe.head()
# Out:
#        Team  offense_downs_offense_downs_3rd Att  \
# 0     Lions                                  242
# 1   Falcons                                  240
# 2      Rams                                  235
# 3      Jets                                  235
# 4  Dolphins                                  230
#
#    offense_downs_offense_downs_3rd Md  offense_downs_offense_downs_4th Att  \
# 0                                  97                                   16
# 1                                 112                                   15
# 2                                  78                                   15
# 3                                  93                                   14
# 4                                  92                                   10
#
#    offense_downs_offense_downs_4th Md  offense_downs_offense_downs_Rec 1st  \
# 0                                  10                                  199
# 1                                  11                                  200
# 2                                   8                                  179
# 3                                   5                                  171
# 4                                   3                                  189
#
#    offense_downs_offense_downs_Rec 1st%  offense_downs_offense_downs_Rush 1st  \
# 0                                  52.0                                    83
# 1                                  55.4                                   111
# 2                                  50.6                                    84
# 3                                  59.4                                   118
# 4                                  56.4                                    91
#
#    offense_downs_offense_downs_Rush 1st%  \
# 0                                   20.5
# 1                                   22.3
# 2                                   19.6
# 3                                   22.1
# 4                                   20.4
#
#    offense_downs_offense_downs_Scrm Plys  ...  \
# 0                                   1064  ...
# 1                                   1097  ...
# 2                                   1053  ...
# 3                                   1087  ...
# 4                                   1040  ...
#
#    offense_rushing_offense_rushing_20+  offense_rushing_offense_rushing_40+  \
# 0                                    9                                    2
# 1                                   12                                    1
# 2                                    9                                    1
# 3                                   11                                    2
# 4                                    5                                    2
#
#          offense_rushing_offense_rushing_Lng  \
# 0                       45
# 1                       55
# 2                      42T
# 3                       53
# 4                       51
#
#    offense_rushing_offense_rushing_Rush 1st  \
# 0                                        83
# 1                                       111
# 2                                        84
# 3                                       118
# 4                                        91
#
#    offense_rushing_offense_rushing_Rush 1st%  \
# 0                                       20.5
# 1                                       22.3
# 2                                       19.6
# 3                                       22.1
# 4                                       20.4
#
#    offense_rushing_offense_rushing_Rush FUM  \
# 0                                         6
# 1                                         4
# 2                                         2
# 3                                        11
# 4                                        12
#
#    offense_scoring_offense_scoring_Rsh TD  \
# 0                                      11
# 1                                      14
# 2                                       9
# 3                                      14
# 4                                       8
#
#    offense_scoring_offense_scoring_Rec TD  \
# 0                                      26
# 1                                      28
# 2                                      18
# 3                                      20
# 4                                      17
#
#    offense_scoring_offense_scoring_Tot TD  \
# 0                                      41
# 1                                      47
# 2                                      27
# 3                                      39
# 4                                      26
#
#    offense_scoring_offense_scoring_2-PT
# 0                                     2
# 1                                     2
# 2                                     0
# 3                                     1
# 4                                     0
#
# [5 rows x 50 columns]

# %%
special_teams_dfs = [
  special_teams_field_goals,
  special_teams_kickoff_returns,
  special_teams_kickoffs,
  special_teams_punt_returns,
  special_teams_punting,
  special_teams_scoring
]

change_dataframes_columns(special_teams_dfs)
special_teams_dataframe = merge_dataframes(special_teams_dfs)

special_teams_dataframe.head()
# Out:
#        Team  special_teams_field_goals_FGM  special_teams_field_goals_Att  \
# 0      Rams                             33                             39
# 1   Raiders                             33                             41
# 2    Eagles                             32                             38
# 3  Dolphins                             30                             41
# 4      Jets                             30                             39
#
#    special_teams_field_goals_FG %       special_teams_field_goals_1-19 > A-M  \
# 0                            84.6                      0_0
# 1                            80.5                      0_0
# 2                            84.2                      0_0
# 3                            73.2                      1_1
# 4                            76.9                      1_1
#
#          special_teams_field_goals_20-29 > A-M  \
# 0                      12_11
# 1                        8_8
# 2                      12_12
# 3                        9_9
# 4                      11_10
#
#          special_teams_field_goals_30-39 > A-M  \
# 0                      14_12
# 1                      14_13
# 2                      12_10
# 3                        5_5
# 4                      16_14
#
#          special_teams_field_goals_40-49 > A-M  \
# 0                        9_7
# 1                       12_8
# 2                       11_9
# 3                      18_11
# 4                        6_3
#
#        special_teams_field_goals_50-59 > A-M  \
# 0                      4_3
# 1                      7_4
# 2                      3_1
# 3                      6_3
# 4                      4_2
#
#          special_teams_field_goals_60+ > A-M  ...  special_teams_punting_40+  \
# 0                      0_0                    ...                          4
# 1                      0_0                    ...                         12
# 2                      0_0                    ...                         15
# 3                      2_1                    ...                          4
# 4                      1_0                    ...                         11
#
#                    special_teams_punting_Lng  special_teams_punting_Sck  \
# 0                       49                                           34
# 1                      73T                                           44
# 2                       91                                           49
# 3                      57T                                           38
# 4                       74                                           28
#
#    special_teams_punting_SckY  data_FGM  data_FG %  data_XPM  data_XP Pct  \
# 0                         244        33       84.6        26         96.3
# 1                         291        33       80.5        43        100.0
# 2                         309        32       84.2        47        100.0
# 3                         228        30       73.2        25        100.0
# 4                         178        30       76.9        37        100.0
#
#    data_KRet TD data_PRet T
# 0             0           0
# 1             3           0
# 2             0           1
# 3             0           0
# 4             2           0
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Cleaning data
#
# Now that we already have 3 main datasets, we can start cleaning data! Cleaning data goes through some process, as such:
# 1. Check null values
# 2. Drop unused columns
# 3. Rename columns and/or values if needed
# 4. Check overall data

# %%
# Cleaning % data
def clean_percent_data(df):
  for column in df.columns:
    if '%' in column:
      df[column] = df[column] / 100

# %%
# Remove special characters from columns
def remove_special_char_columns(df):
  for column in df.columns:
    new_name = column.lower().replace(' ','_').replace('%', '_perc')
    df.rename(columns={
        column : new_name
    }, inplace=True)

# %% [markdown]
# ### Cleaning defense data

# %%
clean_percent_data(defense_dataframe)

# %%
remove_special_char_columns(defense_dataframe)

# %%
defense_dataframe.head()
# Out:
#        team  defense_downs_3rd_att  defense_downs_3rd_md  \
# 0     Lions                    198                    77
# 1   Falcons                    201                    79
# 2      Rams                    221                    74
# 3      Jets                    219                    81
# 4  Dolphins                    226                    84
#
#    defense_downs_4th_att  defense_downs_4th_md  defense_downs_rec_1st  \
# 0                     12                     5                    187
# 1                     17                     9                    183
# 2                     12                     6                    191
# 3                      6                     4                    169
# 4                     22                     8                    166
#
#    defense_downs_rec_1st_perc_  defense_downs_rush_1st  \
# 0                        0.567                      98
# 1                        0.503                      87
# 2                        0.582                      88
# 3                        0.628                      70
# 4                        0.576                      84
#
#    defense_downs_rush_1st_perc_  defense_downs_scrm_plys  ...  \
# 0                         0.221                     1005  ...
# 1                         0.238                      957  ...
# 2                         0.218                     1017  ...
# 3                         0.172                      979  ...
# 4                         0.188                      988  ...
#
#    defense_rushing_rush_1st  defense_rushing_rush_1st_perc_  \
# 0                        98                           0.221
# 1                        87                           0.238
# 2                        88                           0.218
# 3                        70                           0.172
# 4                        84                           0.188
#
#    defense_rushing_rush_fum  defense_scoring_fr_td  defense_scoring_sfty  \
# 0                         8                      1                     1
# 1                         8                      1                     0
# 2                         5                      0                     0
# 3                        12                      0                     0
# 4                         4                      1                     1
#
#    defense_scoring_int_td  defense_tackles_sck  defense_tackles_comb  \
# 0                       2                   44                   949
# 1                       2                   31                   873
# 2                       0                   43                   861
# 3                       3                   40                   835
# 4                       0                   39                   869
#
#    defense_tackles_asst defense_tackles_solo
# 0                   246                  743
# 1                   179                  686
# 2                   127                  770
# 3                   181                  633
# 4                   156                  739
#
# [5 rows x 62 columns]

# %%
defense_dataframe.describe()
# Out:
#        defense_downs_3rd Att  defense_downs_3rd Md  defense_downs_4th Att  \
# count             480.000000            480.000000             480.000000
# mean              212.808333             83.325000              17.945833
# std                12.943620              9.908907               6.588183
# min               176.000000             47.000000               4.000000
# 25%               204.000000             76.750000              13.000000
# 50%               213.000000             83.000000              17.000000
# 75%               222.000000             89.250000              22.000000
# max               250.000000            112.000000              41.000000
#
#        defense_downs_4th Md  defense_downs_Rec 1st  defense_downs_Rec 1st%  \
# count            480.000000             480.000000              480.000000
# mean               9.106250             193.245833               54.745417
# std                4.146982              20.256136                3.796078
# min                0.000000             136.000000               44.300000
# 25%                6.000000             180.750000               52.175000
# 50%                9.000000             192.000000               54.700000
# 75%               12.000000             205.250000               57.300000
# max               22.000000             253.000000               66.100000
#
#        defense_downs_Rush 1st  defense_downs_Rush 1st%  \
# count              480.000000               480.000000
# mean               101.287500                23.170833
# std                 18.750216                 2.860184
# min                 53.000000                15.000000
# 25%                 88.000000                21.200000
# 50%                100.000000                23.300000
# 75%                112.250000                25.100000
# max                179.000000                30.400000
#
#        defense_downs_Scrm Plys         year  ...  defense_rushing_Rush 1st  \
# count               480.000000   480.000000  ...                480.000000
# mean               1036.495833  2017.000000  ...                101.287500
# std                  48.749027     4.325001  ...                 18.750216
# min                 921.000000  2010.000000  ...                 53.000000
# 25%                 999.000000  2013.000000  ...                 88.000000
# 50%                1033.000000  2017.000000  ...                100.000000
# 75%                1073.250000  2021.000000  ...                112.250000
# max                1201.000000  2024.000000  ...                179.000000
#
#        defense_rushing_Rush 1st%  defense_rushing_Rush FUM  \
# count                 480.000000                480.000000
# mean                   23.170833                  6.581250
# std                     2.860184                  2.750149
# min                    15.000000                  1.000000
# 25%                    21.200000                  5.000000
# 50%                    23.300000                  6.000000
# 75%                    25.100000                  8.000000
# max                    30.400000                 19.000000
#
#        defense_scoring_FR TD  defense_scoring_SFTY  defense_scoring_INT TD  \
# count             480.000000            480.000000              480.000000
# mean                0.750000              0.439583                1.418750
# std                 0.888338              0.681163                1.281661
# min                 0.000000              0.000000                0.000000
# 25%                 0.000000              0.000000                0.000000
# 50%                 1.000000              0.000000                1.000000
# 75%                 1.000000              1.000000                2.000000
# max                 5.000000              3.000000                8.000000
#
#        defense_tackles_Sck  defense_tackles_Comb  defense_tackles_Asst  \
# count           480.000000            480.000000            480.000000
# mean             38.439583            974.177083            293.533333
# std               8.237630             83.856896             79.167926
# min              13.000000            811.000000            109.000000
# 25%              33.000000            912.000000            234.000000
# 50%              39.000000            962.500000            291.000000
# 75%              44.000000           1032.250000            353.000000
# max              70.000000           1261.000000            531.000000
#
#        defense_tackles_Solo
# count            480.000000
# mean             684.752083
# std               50.491065
# min              570.000000
# 25%              648.000000
# 50%              678.500000
# 75%              717.250000
# max              850.000000
#
# [8 rows x 57 columns]

# %% [markdown]
# ### Cleaning offense data

# %%
clean_percent_data(offense_dataframe)

# %%
remove_special_char_columns(offense_dataframe)

# %%
offense_dataframe.head()
# Out:
#        team  offense_downs_offense_downs_3rd_att  \
# 0     Lions                                  242
# 1   Falcons                                  240
# 2      Rams                                  235
# 3      Jets                                  235
# 4  Dolphins                                  230
#
#    offense_downs_offense_downs_3rd_md  offense_downs_offense_downs_4th_att  \
# 0                                  97                                   16
# 1                                 112                                   15
# 2                                  78                                   15
# 3                                  93                                   14
# 4                                  92                                   10
#
#    offense_downs_offense_downs_4th_md  offense_downs_offense_downs_rec_1st  \
# 0                                  10                                  199
# 1                                  11                                  200
# 2                                   8                                  179
# 3                                   5                                  171
# 4                                   3                                  189
#
#    offense_downs_offense_downs_rec_1st_perc_  \
# 0                                      0.520
# 1                                      0.554
# 2                                      0.506
# 3                                      0.594
# 4                                      0.564
#
#    offense_downs_offense_downs_rush_1st  \
# 0                                    83
# 1                                   111
# 2                                    84
# 3                                   118
# 4                                    91
#
#    offense_downs_offense_downs_rush_1st_perc_  \
# 0                                       0.205
# 1                                       0.223
# 2                                       0.196
# 3                                       0.221
# 4                                       0.204
#
#    offense_downs_offense_downs_scrm_plys  ...  \
# 0                                   1064  ...
# 1                                   1097  ...
# 2                                   1053  ...
# 3                                   1087  ...
# 4                                   1040  ...
#
#    offense_rushing_offense_rushing_20+  offense_rushing_offense_rushing_40+  \
# 0                                    9                                    2
# 1                                   12                                    1
# 2                                    9                                    1
# 3                                   11                                    2
# 4                                    5                                    2
#
#          offense_rushing_offense_rushing_lng  \
# 0                       45
# 1                       55
# 2                      42T
# 3                       53
# 4                       51
#
#    offense_rushing_offense_rushing_rush_1st  \
# 0                                        83
# 1                                       111
# 2                                        84
# 3                                       118
# 4                                        91
#
#    offense_rushing_offense_rushing_rush_1st_perc_  \
# 0                                           0.205
# 1                                           0.223
# 2                                           0.196
# 3                                           0.221
# 4                                           0.204
#
#    offense_rushing_offense_rushing_rush_fum  \
# 0                                         6
# 1                                         4
# 2                                         2
# 3                                        11
# 4                                        12
#
#    offense_scoring_offense_scoring_rsh_td  \
# 0                                      11
# 1                                      14
# 2                                       9
# 3                                      14
# 4                                       8
#
#    offense_scoring_offense_scoring_rec_td  \
# 0                                      26
# 1                                      28
# 2                                      18
# 3                                      20
# 4                                      17
#
#    offense_scoring_offense_scoring_tot_td  \
# 0                                      41
# 1                                      47
# 2                                      27
# 3                                      39
# 4                                      26
#
#    offense_scoring_offense_scoring_2-pt
# 0                                     2
# 1                                     2
# 2                                     0
# 3                                     1
# 4                                     0
#
# [5 rows x 50 columns]

# %%
offense_dataframe.describe()
# Out:
#        offense_downs_offense_downs_3rd_att  \
# count                           480.000000
# mean                            212.808333
# std                              14.505658
# min                             176.000000
# 25%                             203.000000
# 50%                             212.000000
# 75%                             223.000000
# max                             257.000000
#
#        offense_downs_offense_downs_3rd_md  \
# count                          480.000000
# mean                            83.325000
# std                             11.158312
# min                             52.000000
# 25%                             76.000000
# 50%                             83.000000
# 75%                             91.000000
# max                            118.000000
#
#        offense_downs_offense_downs_4th_att  \
# count                           480.000000
# mean                             17.945833
# std                               7.045423
# min                               4.000000
# 25%                              13.000000
# 50%                              16.500000
# 75%                              22.000000
# max                              48.000000
#
#        offense_downs_offense_downs_4th_md  \
# count                          480.000000
# mean                             9.106250
# std                              4.290004
# min                              0.000000
# 25%                              6.000000
# 50%                              8.000000
# 75%                             12.000000
# max                             24.000000
#
#        offense_downs_offense_downs_rec_1st  \
# count                           480.000000
# mean                            193.245833
# std                              29.634129
# min                             109.000000
# 25%                             171.000000
# 50%                             192.000000
# 75%                             211.000000
# max                             293.000000
#
#        offense_downs_offense_downs_rec_1st_perc_  \
# count                                  480.00000
# mean                                     0.54686
# std                                      0.04377
# min                                      0.41700
# 25%                                      0.51700
# 50%                                      0.54600
# 75%                                      0.57500
# max                                      0.67100
#
#        offense_downs_offense_downs_rush_1st  \
# count                            480.000000
# mean                             101.287500
# std                               22.166212
# min                               56.000000
# 25%                               85.000000
# 50%                               98.000000
# 75%                              113.000000
# max                              188.000000
#
#        offense_downs_offense_downs_rush_1st_perc_  \
# count                                  480.000000
# mean                                     0.231104
# std                                      0.031700
# min                                      0.159000
# 25%                                      0.208750
# 50%                                      0.230000
# 75%                                      0.252000
# max                                      0.318000
#
#        offense_downs_offense_downs_scrm_plys         year  ...  \
# count                             480.000000   480.000000  ...
# mean                             1036.495833  2017.000000  ...
# std                                53.142067     4.325001  ...
# min                               878.000000  2010.000000  ...
# 25%                              1002.000000  2013.000000  ...
# 50%                              1032.000000  2017.000000  ...
# 75%                              1073.000000  2021.000000  ...
# max                              1191.000000  2024.000000  ...
#
#        offense_rushing_offense_rushing_td  \
# count                          480.000000
# mean                            13.685417
# std                              5.130753
# min                              3.000000
# 25%                             10.000000
# 50%                             13.000000
# 75%                             17.000000
# max                             32.000000
#
#        offense_rushing_offense_rushing_20+  \
# count                           480.000000
# mean                             10.833333
# std                               4.726037
# min                               2.000000
# 25%                               7.000000
# 50%                              10.000000
# 75%                              13.000000
# max                              33.000000
#
#        offense_rushing_offense_rushing_40+  \
# count                           480.000000
# mean                              2.066667
# std                               1.662472
# min                               0.000000
# 25%                               1.000000
# 50%                               2.000000
# 75%                               3.000000
# max                               8.000000
#
#        offense_rushing_offense_rushing_rush_1st  \
# count                                480.000000
# mean                                 101.287500
# std                                   22.166212
# min                                   56.000000
# 25%                                   85.000000
# 50%                                   98.000000
# 75%                                  113.000000
# max                                  188.000000
#
#        offense_rushing_offense_rushing_rush_1st_perc_  \
# count                                      480.000000
# mean                                         0.231104
# std                                          0.031700
# min                                          0.159000
# 25%                                          0.208750
# 50%                                          0.230000
# 75%                                          0.252000
# max                                          0.318000
#
#        offense_rushing_offense_rushing_rush_fum  \
# count                                480.000000
# mean                                   6.581250
# std                                    2.982493
# min                                    0.000000
# 25%                                    5.000000
# 50%                                    6.000000
# 75%                                    8.000000
# max                                   19.000000
#
#        offense_scoring_offense_scoring_rsh_td  \
# count                              480.000000
# mean                                13.685417
# std                                  5.130753
# min                                  3.000000
# 25%                                 10.000000
# 50%                                 13.000000
# 75%                                 17.000000
# max                                 32.000000
#
#        offense_scoring_offense_scoring_rec_td  \
# count                              480.000000
# mean                                24.793750
# std                                  7.594991
# min                                  8.000000
# 25%                                 20.000000
# 50%                                 24.000000
# 75%                                 29.000000
# max                                 55.000000
#
#        offense_scoring_offense_scoring_tot_td  \
# count                              480.000000
# mean                                41.479167
# std                                  9.950167
# min                                 17.000000
# 25%                                 34.750000
# 50%                                 41.000000
# 75%                                 48.000000
# max                                 76.000000
#
#        offense_scoring_offense_scoring_2-pt
# count                            480.000000
# mean                               1.481250
# std                                1.487478
# min                                0.000000
# 25%                                0.000000
# 50%                                1.000000
# 75%                                2.000000
# max                                8.000000
#
# [8 rows x 46 columns]

# %% [markdown]
# ### Cleaning special teams data

# %%
clean_percent_data(special_teams_dataframe)

# %%
remove_special_char_columns(special_teams_dataframe)

# %%
special_teams_dataframe.head()
# Out:
#        team  special_teams_field_goals_fgm  special_teams_field_goals_att  \
# 0      Rams                             33                             39
# 1   Raiders                             33                             41
# 2    Eagles                             32                             38
# 3  Dolphins                             30                             41
# 4      Jets                             30                             39
#
#    special_teams_field_goals_fg__perc_  \
# 0                                0.846
# 1                                0.805
# 2                                0.842
# 3                                0.732
# 4                                0.769
#
#         special_teams_field_goals_1-19_>_a-m  \
# 0                      0_0
# 1                      0_0
# 2                      0_0
# 3                      1_1
# 4                      1_1
#
#          special_teams_field_goals_20-29_>_a-m  \
# 0                      12_11
# 1                        8_8
# 2                      12_12
# 3                        9_9
# 4                      11_10
#
#          special_teams_field_goals_30-39_>_a-m  \
# 0                      14_12
# 1                      14_13
# 2                      12_10
# 3                        5_5
# 4                      16_14
#
#          special_teams_field_goals_40-49_>_a-m  \
# 0                        9_7
# 1                       12_8
# 2                       11_9
# 3                      18_11
# 4                        6_3
#
#        special_teams_field_goals_50-59_>_a-m  \
# 0                      4_3
# 1                      7_4
# 2                      3_1
# 3                      6_3
# 4                      4_2
#
#          special_teams_field_goals_60+_>_a-m  ...  special_teams_punting_40+  \
# 0                      0_0                    ...                          4
# 1                      0_0                    ...                         12
# 2                      0_0                    ...                         15
# 3                      2_1                    ...                          4
# 4                      1_0                    ...                         11
#
#                    special_teams_punting_lng  special_teams_punting_sck  \
# 0                       49                                           34
# 1                      73T                                           44
# 2                       91                                           49
# 3                      57T                                           38
# 4                       74                                           28
#
#    special_teams_punting_scky  data_fgm  data_fg__perc_  data_xpm  \
# 0                         244        33           0.846        26
# 1                         291        33           0.805        43
# 2                         309        32           0.842        47
# 3                         228        30           0.732        25
# 4                         178        30           0.769        37
#
#    data_xp_pct  data_kret_td data_pret_t
# 0         96.3             0           0
# 1        100.0             3           0
# 2        100.0             0           1
# 3        100.0             0           0
# 4        100.0             2           0
#
# [5 rows x 65 columns]

# %%
special_teams_dataframe.describe()
# Out:
#        special_teams_field_goals_fgm  special_teams_field_goals_att  \
# count                     480.000000                      480.00000
# mean                       26.597917                       31.56875
# std                         5.553572                        5.77044
# min                         8.000000                       16.00000
# 25%                        23.000000                       28.00000
# 50%                        26.000000                       31.00000
# 75%                        30.000000                       36.00000
# max                        44.000000                       52.00000
#
#        special_teams_field_goals_fg__perc_  special_teams_field_goals_lng  \
# count                           480.000000                     480.000000
# mean                              0.840829                      54.333333
# std                               0.071474                       3.449204
# min                               0.444000                      43.000000
# 25%                               0.798500                      52.000000
# 50%                               0.846000                      54.000000
# 75%                               0.893500                      56.000000
# max                               1.000000                      66.000000
#
#        special_teams_field_goals_fg_blk         year  \
# count                         480.00000   480.000000
# mean                            0.63125  2017.000000
# std                             0.84217     4.325001
# min                             0.00000  2010.000000
# 25%                             0.00000  2013.000000
# 50%                             0.00000  2017.000000
# 75%                             1.00000  2021.000000
# max                             5.00000  2024.000000
#
#        special_teams_kickoff_returns_avg  special_teams_kickoff_returns_ret  \
# count                         480.000000                         480.000000
# mean                           23.029583                          35.395833
# std                             2.766705                          12.503093
# min                            14.600000                           9.000000
# 25%                            21.200000                          27.000000
# 50%                            22.900000                          34.000000
# 75%                            24.900000                          42.000000
# max                            32.100000                          84.000000
#
#        special_teams_kickoff_returns_yds  \
# count                         480.000000
# mean                          818.545833
# std                           308.174804
# min                           145.000000
# 25%                           604.750000
# 50%                           786.000000
# 75%                          1003.250000
# max                          2084.000000
#
#        special_teams_kickoff_returns_kret_td  ...  special_teams_punting_20+  \
# count                             480.000000  ...                 480.000000
# mean                                0.258333  ...                  50.491667
# std                                 0.524885  ...                  10.021477
# min                                 0.000000  ...                  28.000000
# 25%                                 0.000000  ...                  43.000000
# 50%                                 0.000000  ...                  51.000000
# 75%                                 0.000000  ...                  57.000000
# max                                 3.000000  ...                  80.000000
#
#        special_teams_punting_40+  special_teams_punting_sck  \
# count                 480.000000                 480.000000
# mean                    8.785417                  38.439583
# std                     3.413377                  10.623785
# min                     1.000000                  14.000000
# 25%                     6.000000                  31.000000
# 50%                     9.000000                  38.000000
# 75%                    11.000000                  46.000000
# max                    21.000000                  85.000000
#
#        special_teams_punting_scky    data_fgm  data_fg__perc_    data_xpm  \
# count                  480.000000  480.000000      480.000000  480.000000
# mean                   253.839583   26.597917        0.840829   36.662500
# std                     75.569441    5.553572        0.071474    9.878735
# min                     63.000000    8.000000        0.444000   16.000000
# 25%                    196.500000   23.000000        0.798500   30.000000
# 50%                    246.000000   26.000000        0.846000   36.000000
# 75%                    304.000000   30.000000        0.893500   43.000000
# max                    504.000000   44.000000        1.000000   75.000000
#
#        data_xp_pct  data_kret_td  data_pret_t
# count   480.000000    480.000000   480.000000
# mean     95.895833      0.258333     0.314583
# std       4.461721      0.524885     0.580652
# min      78.800000      0.000000     0.000000
# 25%      93.600000      0.000000     0.000000
# 50%      97.000000      0.000000     0.000000
# 75%     100.000000      0.000000     1.000000
# max     100.000000      3.000000     4.000000
#
# [8 rows x 55 columns]
