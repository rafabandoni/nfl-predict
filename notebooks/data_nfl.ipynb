# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/nfl_data.parquet')
df.head()
# Out:
#   Week  Day        Date    Time             Winner/tie H/A  \
# 0    1  Thu  2023-09-07  8:20PM          Detroit Lions   @
# 1    1  Sun  2023-09-10  1:00PM        Atlanta Falcons
# 2    1  Sun  2023-09-10  1:00PM       Cleveland Browns
# 3    1  Sun  2023-09-10  1:00PM   Jacksonville Jaguars   @
# 4    1  Sun  2023-09-10  1:00PM  Washington Commanders
#
#             Loser/tie Pts Allowed Winner Pts Allowed Loser Yds Gained TOs  \
# 0  Kansas City Chiefs                 21                20        368   1
# 1   Carolina Panthers                 24                10        221   0
# 2  Cincinnati Bengals                 24                 3        350   2
# 3  Indianapolis Colts                 31                21        342   2
# 4   Arizona Cardinals                 20                16        248   3
#
#   Yds Allowed Opp TOs  Tm Performance  Opp Performance  Spread  Spread Prcntl
# 0         316       1       -0.735596         0.484609       1       0.137920
# ...
