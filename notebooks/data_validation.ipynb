# %%
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('../data/nfl_stats.parquet')
df.head()
# Out:
#          date               team_a  home              team_b  team_a_pts  \
# 0  2022-09-08        Buffalo Bills   1.0    Los Angeles Rams          31
# 1  2022-09-11   New Orleans Saints   1.0     Atlanta Falcons          27
# 2  2022-09-11     Cleveland Browns   1.0   Carolina Panthers          26
# 4  2022-09-11  Pittsburgh Steelers   1.0  Cincinnati Bengals          23
# 6  2022-09-11  Philadelphia Eagles   1.0       Detroit Lions          38
#
#    team_b_pts  team_a_yds  team_a_turnovers  team_b_yds  team_b_turnovers  \
# 0          10         413                 4         243                 3
# 1          26         385                 1         416                 2
# 2          24         355                 0         261                 1
# 4          20         267                 0         432                 5
# 6          35         455                 0         386                 1
#
#    pts_per_year_team_a  pts_per_year_team_b outcome
# 0                   28                   18  team_a
# 1                   20                   21  team_a
# 2                   21                   20  team_a
# 4                   17                   26  team_a
# 6                   29                   26  team_a

# %%
features = [
    'team_a_yds',
    'team_a_turnovers',
    'team_b_yds',
    'team_b_turnovers',
    'pts_per_year_team_a',
    'pts_per_year_team_b'
]

X = df_outcome[features]
y = df_outcome['outcome']

arvore = tree.DecisionTreeClassifier()
arvore.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(dpi=500)
tree.plot_tree(
    arvore,
    class_names=arvore.classes_,
    feature_names=features,
    filled=True,
    max_depth=4
);

# %%
print(features)
# Out:
# ['team_a_yds', 'team_a_turnovers', 'team_b_yds', 'team_b_turnovers', 'pts_per_year_team_a', 'pts_per_year_team_b']

# %%
predict = arvore.predict([[351, 11, 349.1, -12, 23.6, 18.9]])[0]
pd.Series(predict)
# Out:
# /Users/rafaelbandoni/Documents/git/nfl-predict/.venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0    team_b
# dtype: object
