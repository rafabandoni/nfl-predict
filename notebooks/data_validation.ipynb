# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/nfl_scrapped.parquet')
df.head()
# Out:
#   week  day        date    time           winner_tie h_a            loserttie  \
# 0    1  Thu  2022-09-08  8:20PM        Buffalo Bills   @     Los Angeles Rams
# 1    1  Sun  2022-09-11  1:00PM   New Orleans Saints   @      Atlanta Falcons
# 2    1  Sun  2022-09-11  1:00PM     Cleveland Browns   @    Carolina Panthers
# 3    1  Sun  2022-09-11  1:00PM        Chicago Bears      San Francisco 49ers
# 4    1  Sun  2022-09-11  1:00PM  Pittsburgh Steelers   @   Cincinnati Bengals
#
#   pts_allowed_winner pts_allowed_loser yds_gained tos yds_allowed opp_tos  \
# 0                 31                10        413   4         243       3
# 1                 27                26        385   1         416       2
# 2                 26                24        355   0         261       1
# 3                 19                10        204   1         331       2
# 4                 23                20        267   0         432       5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   week                557 non-null    object
#  1   day                 557 non-null    object
#  2   date                557 non-null    object
#  3   time                557 non-null    object
#  4   winner_tie          557 non-null    object
#  5   h_a                 557 non-null    object
#  6   loserttie           557 non-null    object
#  7   pts_allowed_winner  557 non-null    object
#  8   pts_allowed_loser   557 non-null    object
#  9   yds_gained          557 non-null    object
#  10  tos                 557 non-null    object
#  11  yds_allowed         557 non-null    object
#  12  opp_tos             557 non-null    object
#  13  tm_performance      557 non-null    float64
#  14  opp_performance     557 non-null    float64
# ...
