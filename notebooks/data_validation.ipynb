# %%
import pandas as pd

# %%
predicted_data = pd.read_parquet('../data/nfl_predicted.parquet')

# %%
predicted_data
# Out:
#           Date             Home Team              Away Team  \
# 0   2024-09-05    Kansas City Chiefs       Baltimore Ravens
# 1   2024-09-06   Philadelphia Eagles      Green Bay Packers
# 2   2024-09-08         Buffalo Bills      Arizona Cardinals
# 3   2024-09-08    New Orleans Saints      Carolina Panthers
# 4   2024-09-08    Indianapolis Colts         Houston Texans
# ..         ...                   ...                    ...
# 257 2025-01-05       Atlanta Falcons      Carolina Panthers
# 256 2025-01-05  New England Patriots          Buffalo Bills
# 270 2025-01-05      Los Angeles Rams       Seattle Seahawks
# 262 2025-01-05    Indianapolis Colts   Jacksonville Jaguars
# 271 2025-01-05        Dallas Cowboys  Washington Commanders
#
#                  Winner
# 0      Baltimore Ravens
# 1     Green Bay Packers
# 2         Buffalo Bills
# 3    New Orleans Saints
# 4    Indianapolis Colts
# ..                  ...
# 257   Carolina Panthers
# 256       Buffalo Bills
# ...
